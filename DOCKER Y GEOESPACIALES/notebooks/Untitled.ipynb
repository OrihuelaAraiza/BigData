# %%
# !pip install geopandas folium shapely pyproj fiona rasterio matplotlib
# Out:
# ...
#   Using cached geopandas-1.1.2-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached folium-0.20.0-py2.py3-none-any.whl.metadata (4.2 kB)
# ...
#   Using cached shapely-2.1.2-cp311-cp311-manylinux2014_aarch64.manylinux_2_17_aarch64.whl.metadata (6.8 kB)
# ...
#   Using cached pyproj-3.7.2-cp311-cp311-manylinux_2_28_aarch64.whl.metadata (31 kB)
# ...
#   Using cached fiona-1.10.1.tar.gz (444 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [2 lines of output]
#       WARNING:root:Failed to get options via gdal-config: [Errno 2] No such file or directory: 'gdal-config'
#       CRITICAL:root:A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#       [end of output]
#
# ...

# %%
import geopandas as gpd
gdf = gpd.read_file("./data/map.geojson")
gdf.head()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 import geopandas as gpd
#       2 gdf = gpd.read_file("./data/map.geojson")
#       3 gdf.head()
#
# ModuleNotFoundError: No module named 'geopandas'

# %%
# !pip install geopandas folium shapely pyproj fiona rasterio matplotlib
# Out:
# ...
#   Using cached geopandas-1.1.2-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached folium-0.20.0-py2.py3-none-any.whl.metadata (4.2 kB)
# ...
#   Using cached shapely-2.1.2-cp311-cp311-manylinux2014_aarch64.manylinux_2_17_aarch64.whl.metadata (6.8 kB)
# ...
#   Using cached pyproj-3.7.2-cp311-cp311-manylinux_2_28_aarch64.whl.metadata (31 kB)
# ...
#   Using cached fiona-1.10.1.tar.gz (444 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [2 lines of output]
#       WARNING:root:Failed to get options via gdal-config: [Errno 2] No such file or directory: 'gdal-config'
#       CRITICAL:root:A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#       [end of output]
#
# ...

# %%
pip install pyogrio
pip install geopandas shapely pyproj
# Out:
#   Cell In[5], line 1
#     pip install pyogrio
#         ^
# SyntaxError: invalid syntax

# %%
# !pip install geopandas folium shapely pyproj fiona rasterio matplotlib
# Out:
# ...
#   Using cached geopandas-1.1.2-py3-none-any.whl.metadata (2.3 kB)
# ...
#   Using cached folium-0.20.0-py2.py3-none-any.whl.metadata (4.2 kB)
# ...
#   Using cached shapely-2.1.2-cp311-cp311-manylinux2014_aarch64.manylinux_2_17_aarch64.whl.metadata (6.8 kB)
# ...
#   Using cached pyproj-3.7.2-cp311-cp311-manylinux_2_28_aarch64.whl.metadata (31 kB)
# ...
#   Using cached fiona-1.10.1.tar.gz (444 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [2 lines of output]
#       WARNING:root:Failed to get options via gdal-config: [Errno 2] No such file or directory: 'gdal-config'
#       CRITICAL:root:A GDAL API version must be specified. Provide a path to gdal-config using a GDAL_CONFIG environment variable or use a GDAL_VERSION environment variable.
#       [end of output]
#
# ...

# %%
# !pip install geopandas matplotlib
# Out:
# ...
#   Using cached geopandas-1.1.2-py3-none-any.whl.metadata (2.3 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.8/52.8 kB 419.4 kB/s eta 0:00:00a 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 2.1 MB/s eta 0:00:00
# ...
#   Using cached pyproj-3.7.2-cp311-cp311-manylinux_2_28_aarch64.whl.metadata (31 kB)
# ...
#   Using cached shapely-2.1.2-cp311-cp311-manylinux2014_aarch64.manylinux_2_17_aarch64.whl.metadata (6.8 kB)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.2/114.2 kB 21.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 341.7/341.7 kB 4.6 MB/s eta 0:00:00a 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.5/9.5 MB 3.1 MB/s eta 0:00:0000:0100:010m
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 329.2/329.2 kB 14.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 4.2 MB/s eta 0:00:0000:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 3.0 MB/s eta 0:00:0000:0100:01
# ...

# %%
import geopandas as gpd
gdf = gpd.read_file("./data/map.geojson")
gdf.head()
# Out:
# ---------------------------------------------------------------------------
# DataSourceError                           Traceback (most recent call last)
# Cell In[8], line 2
#       1 import geopandas as gpd
# ----> 2 gdf = gpd.read_file("./data/map.geojson")
#       3 gdf.head()
#
# File /opt/conda/lib/python3.11/site-packages/geopandas/io/file.py:316, in _read_file(filename, bbox, mask, columns, rows, engine, **kwargs)
#     313             filename = response.read()
#     315 if engine == "pyogrio":
# --> 316     return _read_file_pyogrio(
#     317         filename, bbox=bbox, mask=mask, columns=columns, rows=rows, **kwargs
#     318     )
#     320 elif engine == "fiona":
#     321     if pd.api.types.is_file_like(filename):
#
# File /opt/conda/lib/python3.11/site-packages/geopandas/io/file.py:576, in _read_file_pyogrio(path_or_bytes, bbox, mask, rows, **kwargs)
#     567     warnings.warn(
# ...

# %%
gdf.plot(figsize=(10, 8), edgecolor="black", cmap="viridis")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 gdf.plot(figsize=(10, 8), edgecolor="black", cmap="viridis")
#
# NameError: name 'gdf' is not defined

# %%
gdf.plot(figsize=(10, 8), edgecolor="black", cmap="viridis")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 gdf.plot(figsize=(10, 8), edgecolor="black", cmap="viridis")
#
# NameError: name 'gdf' is not defined

# %%
import geopandas as gpd
gdf = gpd.read_file("./data/map.geojson")
gdf.head()
# Out:
# ---------------------------------------------------------------------------
# DataSourceError                           Traceback (most recent call last)
# Cell In[11], line 2
#       1 import geopandas as gpd
# ----> 2 gdf = gpd.read_file("./data/map.geojson")
#       3 gdf.head()
#
# File /opt/conda/lib/python3.11/site-packages/geopandas/io/file.py:316, in _read_file(filename, bbox, mask, columns, rows, engine, **kwargs)
#     313             filename = response.read()
#     315 if engine == "pyogrio":
# --> 316     return _read_file_pyogrio(
#     317         filename, bbox=bbox, mask=mask, columns=columns, rows=rows, **kwargs
#     318     )
#     320 elif engine == "fiona":
#     321     if pd.api.types.is_file_like(filename):
#
# File /opt/conda/lib/python3.11/site-packages/geopandas/io/file.py:576, in _read_file_pyogrio(path_or_bytes, bbox, mask, rows, **kwargs)
#     567     warnings.warn(
# ...

# %%
import geopandas as gpd
gdf = gpd.read_file("./data/ARCHIVO.geojson")
gdf.head()
# Out:
# ---------------------------------------------------------------------------
# DataSourceError                           Traceback (most recent call last)
# Cell In[1], line 2
#       1 import geopandas as gpd
# ----> 2 gdf = gpd.read_file("./data/ARCHIVO.geojson")
#       3 gdf.head()
#
# File /opt/conda/lib/python3.11/site-packages/geopandas/io/file.py:316, in _read_file(filename, bbox, mask, columns, rows, engine, **kwargs)
#     313             filename = response.read()
#     315 if engine == "pyogrio":
# --> 316     return _read_file_pyogrio(
#     317         filename, bbox=bbox, mask=mask, columns=columns, rows=rows, **kwargs
#     318     )
#     320 elif engine == "fiona":
#     321     if pd.api.types.is_file_like(filename):
#
# File /opt/conda/lib/python3.11/site-packages/geopandas/io/file.py:576, in _read_file_pyogrio(path_or_bytes, bbox, mask, rows, **kwargs)
#     567     warnings.warn(
# ...

# %%
import geopandas as gpd
gdf = gpd.read_file("./data/map.geojson")
gdf.head()
# Out:
# ---------------------------------------------------------------------------
# DataSourceError                           Traceback (most recent call last)
# Cell In[2], line 2
#       1 import geopandas as gpd
# ----> 2 gdf = gpd.read_file("./data/map.geojson")
#       3 gdf.head()
#
# File /opt/conda/lib/python3.11/site-packages/geopandas/io/file.py:316, in _read_file(filename, bbox, mask, columns, rows, engine, **kwargs)
#     313             filename = response.read()
#     315 if engine == "pyogrio":
# --> 316     return _read_file_pyogrio(
#     317         filename, bbox=bbox, mask=mask, columns=columns, rows=rows, **kwargs
#     318     )
#     320 elif engine == "fiona":
#     321     if pd.api.types.is_file_like(filename):
#
# File /opt/conda/lib/python3.11/site-packages/geopandas/io/file.py:576, in _read_file_pyogrio(path_or_bytes, bbox, mask, rows, **kwargs)
#     567     warnings.warn(
# ...

# %%
import geopandas as gpd
gdf = gpd.read_file("/data/map.geojson")
gdf.head()
# Out:
# ---------------------------------------------------------------------------
# DataSourceError                           Traceback (most recent call last)
# Cell In[3], line 2
#       1 import geopandas as gpd
# ----> 2 gdf = gpd.read_file("/data/map.geojson")
#       3 gdf.head()
#
# File /opt/conda/lib/python3.11/site-packages/geopandas/io/file.py:316, in _read_file(filename, bbox, mask, columns, rows, engine, **kwargs)
#     313             filename = response.read()
#     315 if engine == "pyogrio":
# --> 316     return _read_file_pyogrio(
#     317         filename, bbox=bbox, mask=mask, columns=columns, rows=rows, **kwargs
#     318     )
#     320 elif engine == "fiona":
#     321     if pd.api.types.is_file_like(filename):
#
# File /opt/conda/lib/python3.11/site-packages/geopandas/io/file.py:576, in _read_file_pyogrio(path_or_bytes, bbox, mask, rows, **kwargs)
#     567     warnings.warn(
# ...

# %%
import geopandas as gpd
gdf = gpd.read_file("../data/map.geojson")
gdf.head()
# Out:
#                                             geometry
# 0  POLYGON ((-99.15529 19.57543, -99.16685 19.574...

# %%
gdf.plot(figsize=(10, 8), edgecolor="black", cmap="viridis")
# Out:
# <Axes: >
